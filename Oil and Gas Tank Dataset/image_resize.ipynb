# %%
#image resize
#In this dataset, the resolution is 0.3m*0.3m
#To keep the same resolution, the images have to be shrink at a ratio of 0.3/1
#The images are 300*300, after shrinking, the size will be smaller than 256*256
#The rest of the image will be filled with gray. 

"""Resize images.
    
Args: 
    path (str): The path of work direction
    new_path (str): The path to save resized images
    filelist (list): a list of original images
    image_path (str): Image path
    im (array): Original image
    w (int): The width of the image
    h (int): The height of the image
    nw (int): Resized width of the image
    nh (int): Resized height of the image
    re_im (array): Resized image
        
Returns: 

"""

from PIL import Image
import numpy as np
import os

path = "./images/"
new_path = "./resize_images/"
filelist = os.listdir(path)

for file in filelist:
    image_path = path + file
    im = Image.open(image_path)
    w, h = im.size
    nw = int(w*(3/10))+1
    nh = int(h*(3/10))+1
    re_im = im.resize((nw, nh), Image.ANTIALIAS)
    new_image = Image.new('RGB', (256, 256), (128, 128, 128))
    new_image.paste(re_im, (0, 0))
    save_path = new_path + file
    new_image.save(save_path)

# %%
import shutil
from lxml.etree import Element,SubElement,tostring
from xml.dom.minidom import parseString
import xml.dom.minidom
import os
import sys
from PIL import Image

# %%
import pandas as pd
import numpy as np
import json
# load data using Python JSON module
with open("C:/Users/rapiduser/Box/EPA STAR 2019 (Community Resistance to Environmental Disasters)/Data/AST Datasets/Oil_Gas_Tank_Dataset/Oil Tanks/labels_coco.json",'r') as f:
    data = json.loads(f.read())
    
# Normalizing data
df_anno = pd.json_normalize(data, record_path =['annotations'])
df_images = pd.json_normalize(data, record_path =['images'])

# %%
len(np.unique(df_anno["image_id"]))
# Out:
# 1595

# %%
#read size of images. 

def readsize(path):
    """Read size of images.
    
    Args: 
        path (str): The path of work direction

        
    Returns: 
        width (int): The width of the image
        height (int): The height of the image
    """
    img=Image.open(path)
    width=img.size[0]
    height=img.size[1]
    return height, width

# %%
#After resizing the images 
#the annotations have to be resized. 
#This function is to write annotations

def writexml(path,filename,num,xmins,ymins,xmaxs,ymaxs,names,height, width):# Nwpu-vhr-10 < 1000*600
    """write xml files for the images.
    
    Args: 
        create nodes in the xml files
  
    Returns: 
        create xml files
    """
    node_root=Element('annotation')

    node_folder=SubElement(node_root,'folder')
    node_folder.text="Oil and Gas Tank Dataset"

    node_filename=SubElement(node_root,'filename')
    node_filename.text="%s" % filename
    
    node_path=SubElement(node_root,'path')
    node_path.text="%s" % path
    
    node_source=SubElement(node_root,"source")
    node_database = SubElement(node_source, 'database')
    node_database.text = 'Unknown'

    node_size=SubElement(node_root,"size")
    node_width = SubElement(node_size, 'width')
    node_width.text = '%s' % width

    node_height = SubElement(node_size, 'height')
    node_height.text = '%s' % height

    node_depth = SubElement(node_size, 'depth')
    node_depth.text = '3'
    for i in range(num):
        node_object = SubElement(node_root, 'object')
        node_name = SubElement(node_object, 'name')
        node_name.text = '%s' % names[i]
        node_name = SubElement(node_object, 'pose')
        node_name.text = '%s' % "unspecified"
        node_name = SubElement(node_object, 'truncated')
        node_name.text = '%s' % "0"
        node_difficult = SubElement(node_object, 'difficult')
        node_difficult.text = '0'
        node_bndbox = SubElement(node_object, 'bndbox')
        node_xmin = SubElement(node_bndbox, 'xmin')
        node_xmin.text = '%s'% xmins[i]
        node_ymin = SubElement(node_bndbox, 'ymin')
        node_ymin.text = '%s' % ymins[i]
        node_xmax = SubElement(node_bndbox, 'xmax')
        node_xmax.text = '%s' % xmaxs[i]
        node_ymax = SubElement(node_bndbox, 'ymax')
        node_ymax.text = '%s' % ymaxs[i]

    xml = tostring(node_root, pretty_print=True)  
    dom = parseString(xml)
    with open(path, 'wb') as f:
        f.write(xml)
    return

# %%
#Annotation resize
#read original annotations and write new xml files. 

from __future__ import division
import os
from PIL import Image
import xml.dom.minidom
import numpy as np

"""Resize annotation.
    
Args: 
    ImgPath (str): The path of the folder containing original images
    Annopath (str): The path of the folder containing original annotation files
    ProcessedPath (str): The path of folder to save new annotation files
    imagelist (list): a list of original images
    image_pre (str): The file name of the image
    ext (str): The extension name of the image
    imgfile (str): The path of the image
    xmlfile (str): The path of the xml file of the image
    DomTree, annotation, filenamelist, filename, objectlist are nodes in the xml file
    xmins, xmaxs, ymins, ymaxs (int): they are the resized locations of bounding box of tanks
    names (str): image names
    ratio (float): resize ratio
    num (int): number of images
    filename_fill, filename_jpg (str): image name
    dealpath (str): path to save new xml file
    imagpath (str): path of the image
    height, width (str): new size 256*256
    
        
Returns: 
    create new xml files
"""


ImgPath = './images/' 
AnnoPath = './xml/'
ProcessedPath = './new_xml/'
 
if not os.path.exists(ProcessedPath):
    os.makedirs(ProcessedPath)

imagelist = os.listdir(ImgPath)
 
for image in imagelist:
    print('a new image:', image)
    image_pre, ext = os.path.splitext(image)
    imgfile = ImgPath + image 
    xmlfile = AnnoPath + image_pre + '.xml'
    
    DomTree = xml.dom.minidom.parse(xmlfile)
    annotation = DomTree.documentElement

    filenamelist = annotation.getElementsByTagName('filename') #[<DOM Element: filename at 0x381f788>]
    filename = filenamelist[0].childNodes[0].data
    objectlist = annotation.getElementsByTagName('object')
    
    count = 0
    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []
    names = []
    for objects in objectlist:
        # print objects
        count = count + 1
        namelist = objects.getElementsByTagName('name')
        # print 'namelist:',namelist
        objectname = namelist[0].childNodes[0].data
        names.append(objectname)
        bndbox = objects.getElementsByTagName('bndbox')
        cropboxes = []
        for box in bndbox:
            try:
                x1_list = box.getElementsByTagName('xmin')
                x1 = int(x1_list[0].childNodes[0].data)
                y1_list = box.getElementsByTagName('ymin')
                y1 = int(y1_list[0].childNodes[0].data)
                x2_list = box.getElementsByTagName('xmax')
                x2 = int(x2_list[0].childNodes[0].data)
                y2_list = box.getElementsByTagName('ymax')
                y2 = int(y2_list[0].childNodes[0].data)
                
                ratio = (int(512*(3/10))+1)/512
                x1_1 = x1*ratio
                y1_1 = y1*ratio
                x2_1 = x2*ratio
                y2_1 = y2*ratio
 
                img = Image.open(imgfile)
                width,height = img.size
 
                xmins.append(x1_1)
                ymins.append(y1_1)
                xmaxs.append(x2_1)
                ymaxs.append(y2_1)
        
            except Exception as e:
                print(e)
    num = count
    print(num)
    print(names)
    filename_fill = image_pre
    filename_jpg = filename_fill + ".jpg"
    dealpath=ProcessedPath+ filename_fill +".xml"
    imagpath = './images/' + filename_fill + ".jpg"
    with open(dealpath, 'w') as f:
        height, width = (256, 256)
        writexml(dealpath,filename_jpg,num,xmins,ymins,xmaxs,ymaxs,names, height, width)
# Out:
# a new image: cold-lake_1-1-0_20041_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-0_20450_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-0_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-0_22495_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-0_24949_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-0_26585_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-0_30266_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-0_32311_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-0_48262_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-0_818_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-10225_13906_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-10225_14315_512_512_0_57088_32256.jpg
# 7
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-10225_30266_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-10225_30675_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-10634_14315_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-11043_29448_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-11043_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-11043_42127_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-11452_20041_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-11452_34765_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-11452_52761_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-11452_53170_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-11861_20041_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-11861_37628_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-11861_52352_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-11861_52761_512_512_0_57088_32256.jpg
# 7
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-11861_53170_512_512_0_57088_32256.jpg
# 11
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-11861_53579_512_512_0_57088_32256.jpg
# 10
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-12270_14315_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-12270_14724_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-12270_15133_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-12270_53579_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-1227_13497_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-1227_29039_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-1227_30675_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-1227_4499_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-1227_47035_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-1227_50307_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-13497_11452_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-13497_37219_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-13497_39264_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-13906_32720_512_512_0_57088_32256.jpg
# 11
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-13906_34765_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-13906_41718_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-13906_42127_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-15133_13497_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-15133_40900_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-15133_42127_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-15133_42536_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-15133_44581_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-15542_34765_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-15542_35174_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-15951_30675_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-15951_37219_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-15951_39264_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-15951_39673_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-16360_15542_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-1636_21677_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-1636_22086_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-1636_22495_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-1636_41718_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-16769_2454_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-16769_33129_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-16769_33538_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-16769_34765_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-17178_13906_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-17178_14315_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-17178_27812_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-17587_11043_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-17587_11452_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-17587_30266_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-17996_9407_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-18405_13906_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-18405_31084_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-18405_33947_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-18405_4090_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-18405_4499_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-18405_9407_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-18814_35992_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-19223_14315_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-19223_14724_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-19223_15542_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-19223_15951_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-19632_13497_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-19632_13906_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-19632_14315_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-19632_14724_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-19632_5317_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-19632_6953_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-20041_2863_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-20041_37628_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-20450_9816_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-2045_31493_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2045_31902_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2045_3272_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-2045_39264_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-2045_44172_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2045_46217_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2045_48671_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-2045_7771_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-20859_7771_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-20859_8180_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-20859_8589_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-20859_8998_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-21268_13906_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-21268_27812_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-21268_4090_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-21268_6135_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-21677_13088_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-22086_2045_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-22086_2454_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-22086_6953_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-22495_23722_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-22495_6544_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-22904_21268_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-22904_23722_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-22904_25767_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-22904_28630_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-22904_29039_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-22904_30266_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-22904_34356_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-22904_36810_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-22904_37219_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-22904_6953_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-23313_11043_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-23313_2045_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-23313_2454_512_512_0_57088_32256.jpg
# 7
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-23313_32720_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-23313_409_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-23313_4499_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-23313_8180_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-23313_9816_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-23722_2045_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-23722_2454_512_512_0_57088_32256.jpg
# 36
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-23722_32720_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-23722_6135_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-23722_8180_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24131_11861_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-24131_1227_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-24131_14724_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-24131_17996_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24131_29448_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24131_31902_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24540_7362_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-2454_3272_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-2454_4090_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2454_4499_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2454_51534_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2454_53170_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2454_7771_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24949_15951_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-24949_24131_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-24949_27812_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-24949_28221_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-24949_30675_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24949_32311_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24949_37219_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-24949_8589_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-25358_12270_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-25358_12679_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-25358_15951_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-25358_18405_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-25358_23722_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-25358_35174_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-25358_8589_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-25767_12270_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-26176_31902_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-26176_32311_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-26585_26994_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26585_28630_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26585_29039_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-26585_31084_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26585_33129_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26585_33538_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26994_10225_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-26994_13497_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-26994_24131_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26994_24540_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-26994_29039_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26994_29448_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-26994_35174_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_10225_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_11861_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_12270_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_13497_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_13906_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_24131_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_24540_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-27403_26994_512_512_0_57088_32256.jpg
# 7
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_27403_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_31902_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_36401_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27403_8180_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-27403_8998_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27812_12270_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27812_28221_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27812_30675_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-27812_33129_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-27812_38446_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-27812_8998_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_21677_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_22086_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_23313_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_24131_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_24540_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_28221_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-28221_28630_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_29857_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-28221_30266_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-28221_32311_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-28221_33947_512_512_0_57088_32256.jpg
# 8
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28221_38446_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-28630_11452_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-28630_24131_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-28630_24540_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2863_1636_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-2863_32311_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-2863_4090_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-2863_4499_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-29039_10225_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-29039_11452_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29039_13088_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29039_31084_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29039_32311_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29039_32720_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29039_35174_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-29039_35583_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29039_35992_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29448_13088_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29448_26994_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29448_27403_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29448_29039_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-29448_30675_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29448_33538_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-29448_36810_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-29857_10634_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29857_11043_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-29857_26994_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-29857_7771_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-30266_10634_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-30266_11043_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-30266_31902_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-30675_9407_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-30675_9816_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-31084_30675_512_512_0_57088_32256.jpg
# 12
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-31084_7362_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-31084_7771_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-31493_21268_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-31493_38037_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-31493_38446_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-31744_21268_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-31744_32720_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-31744_35174_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-3272_53170_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-3272_53579_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-3681_53170_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-3681_53579_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-3681_8589_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-4090_409_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-4090_48671_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-4090_4908_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-4090_5726_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-409_26176_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-409_33129_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-409_5726_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-4499_20041_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-4499_409_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-4499_41718_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-4499_43763_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-4499_44172_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-4499_46217_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-4499_46626_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-4499_48671_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-4499_51534_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-4499_9816_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-4908_15542_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-4908_15951_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-4908_51534_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-5317_1636_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5317_20041_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-5317_2045_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5317_3272_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5317_36810_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5317_3681_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-5317_37219_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5317_5317_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-5726_1227_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5726_20041_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5726_20450_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-5726_2863_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-6135_2863_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-6135_4090_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6135_4499_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6544_39264_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-6544_4090_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6544_41718_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-6544_44172_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6544_44581_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6544_4499_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6544_46217_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6544_46626_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6544_48671_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6953_0_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-6953_409_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-7362_36810_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-7362_52352_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-7771_19632_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-7771_23313_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-7771_23722_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-7771_49489_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-7771_49898_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-8180_23313_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-8180_23722_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-8180_30266_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-8180_48671_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-818_26176_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-818_27403_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-818_38037_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-818_50307_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-818_5726_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-8589_11861_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-8589_2863_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-8589_37219_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-8589_39673_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-8589_47444_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-8589_50307_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-8998_27812_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-8998_28221_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-8998_37219_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-9407_11452_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-9407_11861_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-1-9407_27812_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-9407_28221_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-9407_42127_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-9407_43763_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-9407_44172_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-1-9816_11452_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-1-9816_29039_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-1-9816_29448_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-0_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-0_22904_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-10225_8589_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-10634_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-10634_23313_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-10634_4090_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-10634_43763_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11043_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11043_22086_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11043_3272_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-11043_3681_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-11043_4090_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-11043_43763_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11043_9407_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11043_9816_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11452_4090_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11452_6135_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-11861_25358_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-11861_4090_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-12270_2454_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-12270_3681_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-12270_44172_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-1227_28221_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-1227_28630_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-12679_3681_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-12679_44581_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-12679_44990_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-12679_54806_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-12679_55215_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-13088_13906_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-13088_25358_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-13088_42945_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-13088_44581_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-13088_54806_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-13088_55215_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-13497_23313_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14315_18405_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-14315_22904_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14315_25358_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14315_25767_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14724_22904_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14724_25358_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14724_25767_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14724_38446_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-14724_40491_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-14724_6953_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15133_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15133_21268_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15133_22904_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15133_6953_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15542_0_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15542_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15542_2454_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15542_409_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15542_46217_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15542_6953_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15951_3681_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-15951_4090_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-16360_46217_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-16360_46626_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-1636_20450_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-1636_25358_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-1636_28630_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-1636_29039_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-1636_31084_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-16769_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-16769_18405_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-16769_2454_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-16769_39264_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-16769_6953_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-16769_7362_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-17587_15951_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17587_4090_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17587_4499_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17587_47444_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17587_48262_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17587_4908_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17996_15133_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17996_17996_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17996_18405_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-17996_48262_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-17996_6953_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-18405_17178_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-18814_16360_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-18814_18814_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-18814_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-18814_26585_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-19223_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-19223_19632_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-19223_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-19223_2454_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-19223_27403_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-19223_45808_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-19223_49489_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-19223_6544_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_0_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_18405_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_18814_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_29039_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_30266_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_31084_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20041_31493_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20450_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20450_11861_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20450_13906_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20450_21677_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-20450_22086_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-20450_27403_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20450_27812_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-20450_409_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20450_8180_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-2045_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-2045_12270_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-2045_18814_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-2045_19223_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-2045_29448_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-2045_30266_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-2045_32720_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-20859_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20859_11861_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20859_15542_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-20859_31902_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-20859_40491_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21268_1227_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21268_13906_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-21268_19632_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-21268_24131_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21268_29039_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-21268_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-21268_30266_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21268_31084_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21268_31493_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21677_10225_512_512_0_57088_32256.jpg
# 7
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-21677_10634_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-21677_11043_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-21677_23313_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21677_31493_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-21677_32720_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-21677_33129_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-22086_10225_512_512_0_57088_32256.jpg
# 15
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22086_10634_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22086_13906_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22495_10225_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22495_10634_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22495_13906_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22495_17178_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-22495_19632_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-22495_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-22495_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-22495_30266_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-22495_33538_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22495_40082_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-22904_4908_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-23313_10634_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23313_42127_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-23313_43354_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-23313_4908_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-23722_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_11861_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_20450_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_30266_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_31493_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_31902_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_32311_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-23722_32720_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-23722_33129_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_33538_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_45399_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_55215_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-23722_9407_512_512_0_57088_32256.jpg
# 7
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-24131_21268_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24131_31493_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24131_31902_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24131_32720_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-24131_33129_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24131_39673_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-24540_15951_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-24540_16360_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-24540_17178_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24540_17587_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-24540_27403_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24540_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24540_41309_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24540_44172_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24540_47444_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-24540_5726_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-2454_9407_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-24949_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24949_17587_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-24949_17996_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24949_28221_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24949_30675_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24949_36810_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24949_41718_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-24949_53988_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-25358_53988_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-25358_55215_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_17996_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-25767_18814_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-25767_2454_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_27812_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_31084_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_33538_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_3681_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_4499_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_48262_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_48671_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-25767_52352_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26176_19223_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26176_2454_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26176_26585_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26176_50307_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26176_7771_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26585_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26585_19223_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-26585_24540_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26585_25358_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26585_25767_512_512_0_57088_32256.jpg
# 1
# ['tank']
# ...
# a new image: cold-lake_1-2-26994_28630_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26994_29857_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-26994_32311_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-26994_33538_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26994_35583_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26994_38446_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26994_41309_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-26994_41718_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-26994_45399_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-26994_45808_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-26994_48262_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-26994_48671_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-26994_55624_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-26994_7362_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27403_16360_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27403_17587_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27403_23313_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27403_24131_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27403_24949_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27403_2863_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-27403_3272_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-27403_50307_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27403_7771_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27812_23313_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27812_24131_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27812_38037_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27812_42945_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-27812_48671_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-28221_10634_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_1227_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-28221_16360_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_18405_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-28221_19632_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_22086_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-28221_23722_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_25358_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_35583_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-28221_41718_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_43763_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-28221_44990_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_4499_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-28221_48671_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-28221_50307_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-28221_50716_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-28221_53170_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-28630_22904_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-2863_9407_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-29039_26176_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-29039_32311_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29039_32720_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29039_34765_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-29039_35992_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29039_3681_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-29039_44172_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29039_49489_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29039_49898_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29039_50307_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-29039_6953_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-29039_7362_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-29448_16360_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-29448_22495_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29448_409_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29448_41718_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29448_44990_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29448_51943_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29448_55624_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-29857_1227_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-29857_16360_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_23722_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_24131_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_2863_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_409_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_45399_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_45808_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_47853_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-29857_51943_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-29857_52352_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30266_38037_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30266_39264_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30266_39673_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-30266_45808_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-30266_46217_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30266_50307_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-30266_50716_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-30266_52352_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-30266_52761_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-30266_54397_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30675_11861_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30675_41309_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30675_42945_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30675_48671_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-30675_50716_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-30675_55215_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31084_1227_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31084_37219_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31084_50307_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31084_50716_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31084_53170_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-31084_56033_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31493_13906_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-31493_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31493_25358_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-31493_25767_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31493_29039_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31493_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31493_31084_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31493_41718_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31493_50716_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31493_53170_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31744_13906_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-31744_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31744_25358_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-31744_25767_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31744_37628_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-31744_41718_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31744_48262_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31744_48671_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-31744_53988_512_512_0_57088_32256.jpg
# 6
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-31744_8180_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-3681_11043_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-3681_18405_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-3681_20041_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-3681_22086_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-3681_30266_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-3681_30675_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-3681_32720_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-3681_44990_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-4090_10225_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-4090_22904_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-409_19223_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-409_25358_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-409_25767_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-409_28630_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-409_29039_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-409_30675_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-4499_28221_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-4908_12679_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-4908_21268_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-4908_28221_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-5317_13906_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-5317_9407_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-5726_9407_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-6135_17587_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6135_20041_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-6135_2045_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-6135_22086_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6135_24540_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-6135_26585_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6135_5726_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-6544_13906_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6544_14315_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6544_20041_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-6544_7771_512_512_0_57088_32256.jpg
# 8
# ['tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-6544_8180_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-6544_818_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-6953_13906_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6953_14315_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6953_23313_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-6953_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-7362_20450_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-7362_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-7362_5726_512_512_0_57088_32256.jpg
# 5
# ['tank', 'tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-7771_0_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-7771_11861_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-7771_12270_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-7771_20450_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-7771_20859_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8180_0_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8180_11861_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8180_12270_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8180_4499_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-8180_4908_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-8180_8180_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8180_8589_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-8180_8998_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-818_25767_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-818_29857_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8589_5726_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-8589_6135_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8998_0_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8998_10634_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-8998_11452_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-8998_2045_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-8998_2454_512_512_0_57088_32256.jpg
# 4
# ['tank', 'tank', 'tank', 'tank']
# a new image: cold-lake_1-2-8998_39673_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-9816_1227_512_512_0_57088_32256.jpg
# 1
# ['tank']
# a new image: cold-lake_1-2-9816_24131_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-9816_24540_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-9816_26585_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
# a new image: cold-lake_1-2-9816_5726_512_512_0_57088_32256.jpg
# 3
# ['tank', 'tank', 'tank']
# a new image: cold-lake_1-2-9816_8589_512_512_0_57088_32256.jpg
# 2
# ['tank', 'tank']
